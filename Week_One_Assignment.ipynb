# %% [markdown]
# # Python Week One

# %% [markdown]
# Hello! The assignment covers basic concepts of python. The assignment is for your learning. You can use the internet. If you get stuck anywhere, feel free to ask us.<br> You can copy this colab file(File-----> Save a copy in Drive) or download to solve in jupyter(File----->Download.ipynb)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Print Class Type of a and b

# %%
a=5
b='Hello'
print(type(a))
print(type(b))
#Print Class Type of a and b
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Take 2 num as input(like cin>> in C++) and swap them without using third variable

# %%
a = int(input())
b = int(input())

a = a^b
b = a^b
a = a^b
print(int(a))
print(int(b))
#Take 2 num as input(like cin>> in C++) and swap them without using third variable
# Out:
# 6
# 4
# <class 'int'>
# 4
# 6

# %% [markdown]
# Print <br> a. length of string <br> b. Indian Institute of Technology //using string slicing,not by print("Indian Institute of Technology") 😅

# %%
string='Indian Institute of Technology Bombay'
print(len(string))
print(string[0:-7:1])
# Out:
# 37
# Indian Institute of Technology

# %% [markdown]
# Add 'c' & 5 to the list
# <br> remove 5th element from the list
# <br>print List elements from 2nd index to 7th

# %%
List=[9,10,11,12,13,14,'a','b']
List.extend(['c',5])
List.pop(5)
print(List[2:7])
# Out:
# [11, 12, 13, 'a', 'b']

# %% [markdown]
# Print <br>a. Hello (using x,y,z)<br>b. He#ll#o (use sep in python 😺)
#
# ---

# %%
x='He'
y='ll'
z='o'
print(x+y+z)
print(x,y,z,sep='#')
# Out:
# Hello
# He#ll#o

# %% [markdown]
# Write function which reverse the list using list slicing

# %%
list = [1,2,5,12,4,69,420]
list[ :: -1]
# Out:
# [420, 69, 4, 12, 5, 2, 1]

# %% [markdown]
# Create a list of tuples from given list having number and its cube in each tuple
# <br> eg Input: list = [1, 2, 3]<br> Output: [(1, 1), (2, 8), (3, 27)]

# %%
l = []
l = [int(no) for no in input().split()]
data = [(x,x*x*x) for x in l]
data
# Out:
# 7  6 12
# [(7, 343), (6, 216), (12, 1728)]

# %% [markdown]
# Find the sum of all items in a dictionary <br>eg
# Input : {‘a’: 100, ‘b’:200, ‘c’:300}<br>
# Output : 600

# %%
data = {'a': 100, 'b': 300, 'c': 400}
v = data.values()
sum(v)
# Out:
# 800

# %% [markdown]
# Write a Python function that takes a list and returns a new list with unique elements of the first list

# %%
l = []
l = [int(item) for item in input().split()]
l = list(set(l))
l
# Out:
# 3 4 4 4 4
# [3, 4]

# %% [markdown]
# Create a list starting from 100 with elements less than 400 and difference between elements is 3 eg.[100,103,...,298]

# %%
x = range(100,400,3)
list = [i for i in x]
list
# Out:
# [100,
#  103,
#  106,
#  109,
#  112,
#  115,
#  118,
#  121,
#  124,
#  127,
#  130,
#  133,
#  136,
#  139,
#  142,
#  145,
#  148,
#  151,
#  154,
#  157,
#  160,
#  163,
#  166,
#  169,
#  172,
#  175,
#  178,
#  181,
#  184,
#  187,
#  190,
#  193,
#  196,
#  199,
#  202,
#  205,
#  208,
#  211,
#  214,
#  217,
#  220,
#  223,
#  226,
#  229,
#  232,
#  235,
#  238,
#  241,
#  244,
#  247,
#  250,
#  253,
#  256,
#  259,
#  262,
#  265,
#  268,
#  271,
#  274,
#  277,
#  280,
#  283,
#  286,
#  289,
#  292,
#  295,
#  298,
#  301,
#  304,
#  307,
#  310,
#  313,
#  316,
#  319,
#  322,
#  325,
#  328,
#  331,
#  334,
#  337,
#  340,
#  343,
#  346,
#  349,
#  352,
#  355,
#  358,
#  361,
#  364,
#  367,
#  370,
#  373,
#  376,
#  379,
#  382,
#  385,
#  388,
#  391,
#  394,
#  397]

# %% [markdown]
# Write lambda function to multiply two num

# %%
a= 3
b= 4
f = lambda a,b : a*b
f(a,b)
# Out:
# 12

# %% [markdown]
# Count the number of even and odd numbers in tuple.

# %%
numbers = (1, 2, 3, 5, 5)
count_odd = 0
count_even = 0
for i in numbers: 
    if i%2==0:
        count_even = count_even +1
    else: 
        count_odd = count_odd +1
print(count_odd,count_even)
# Out:
# 4 1

# %% [markdown]
# Write a Python program that prints all the numbers from 0 to 10 except 3,6 and 7.

# %%
x = range(0,10)
for i in x:
    if(i!=3 and i!= 6 and i!=7):
        print(i)
# Out:
# 0
# 1
# 2
# 4
# 5
# 8
# 9

# %% [markdown]
# ![image.png](data:image/png;base64,...)
